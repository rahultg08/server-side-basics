# %%
import requests

# %%
url = 'https://www.ibm.com/'

# %% [markdown]
# GET Request

# %%
r = requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %%
r.request.headers
# Out:
# {'User-Agent': 'python-requests/2.25.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': '_abck=F033F89D45B5AE22C194A8F31DB9937B~-1~~-1~-1~-1; bm_sz=EA9E1F0D8BE934433D883596C3F0287E~~3294276~3753268'}

# %%
r.request.body

# %%
headers = r.headers

# %%
headers
# Out:
# {'Server': 'Apache', 'Last-Modified': 'Fri, 10 Feb 2023 16:57:49 GMT', 'ETag': '"125fc-5f45b65b483b2-gzip"', 'Accept-Ranges': 'bytes', 'Content-Type': 'text/html', 'Cache-Control': 'max-age=3600', 'Expires': 'Mon, 13 Feb 2023 16:54:13 GMT', 'X-Akamai-Transformed': '9 16605 0 pmb=mTOE,2', 'Content-Encoding': 'gzip', 'Date': 'Mon, 13 Feb 2023 15:54:13 GMT', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive, Transfer-Encoding', 'Vary': 'Accept-Encoding', 'x-content-type-options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Content-Security-Policy': 'upgrade-insecure-requests', 'Strict-Transport-Security': 'max-age=31536000'}

# %%
headers['Server']
# Out:
# 'Apache'

# %%
headers['date']
# Out:
# 'Mon, 13 Feb 2023 15:54:13 GMT'

# %%
headers['Content-Type']
# Out:
# 'text/html'

# %%
r.encoding
# Out:
# 'ISO-8859-1'

# %%
r.text
# Out:
# '<!DOCTYPE html><html lang="en-US"><head><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><title>IBM - United States</title><link rel="canonical" href="https://www.ibm.com/us-en"/><meta name="robots" content="index,follow"/><meta name="description" content="For more than a century IBM has been dedicated to every client&#x27;s success and to creating innovations that matter for the world"/><meta name="keywords" content="IBM"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta http-equiv="Cache-Control" content="no-cache, no-store, must-revalidate"/><meta http-equiv="Pragma" content="no-cache"/><meta http-equiv="Expires" content="0"/><link rel="icon" href="//www.ibm.com/favicon.ico"/><meta name="ibmdotcom.version.react" content="^1.38.0"/><meta name="ibmdotcom.version.styles" content="^1.38.0"/><meta name="ibmdotcom.build.time" content="2023-02-10T16:57:15.594Z"/><meta name="dcterms.date" content="2015-10-01"/><meta name="dcterms.rights" content="Â© Copyright IBM Corp. 2020"/><meta name="geo.country" content="US"/><script>digitalData={"page":{"category":{"primaryCategory":"SB03"},"pageInfo":{"effectiveDate":"2022-12-15","expiryDate":"2027-12-15","language":"en-us","publishDate":"2022-12-15","publisher":"IBM Corporation","version":"Carbon:IBM.com Library v1.32.0","ibm":{"contentDelivery":"Hand coded","contentProducer":"Lance Tappana","country":"us","industry":"ZZ","owner":"Corporate Webmaster/New York/IBM","siteID":"GLOBAL","subject":"IBM000","type":"CT052","messaging":{"routing":{"focusArea":"Miscellaneous - Cross IBM","languageCode":"en","regionCode":"US"},"translation":{"languageCode":"en","regionCode":"US"}}},"hotjar":{"enabled":0}}}};</script><script>\n            window.hj=window.hj||function(){(hj.q=hj.q||[]).push(arguments)};\n            window.hj(\'tagRecording\', [\'hjLoaded\']);\n            document.addEventListener(\'onMegaMenuToggle\', e => {\n              if(e.target.getAttribute("data-title") == \'products-solutions\') {\n                window.hj(\'trigger\', \'MM_products-solutions\');\n              }\n              if(e.target.getAttribute("data-title") == \'services-consulting\') {\n                window.hj(\'trigger\', \'MM_services-consulting\');\n              }\n              if(e.target.getAttribute("data-title") == \'learn-support\') {\n                window.hj(\'trigger\', \'MM_learn-support\');\n              }\n              if(e.target.getAttribute("data-title") == \'explore-more\') {\n                window.hj(\'trigger\', \'MM_explore-more\');\n              }\n            });\n\n            </script><script type="module" src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/tag/v2/alpha/masthead.min.js"></script><link rel="alternate" hrefLang="en-us" href="https://www.ibm.com/us-en"/><link rel="alternate" hrefLang="x-default" href="https://www.ibm.com"/><link rel="alternate" hrefLang="en-af" href="https://www.ibm.com/af-en"/><link rel="alternate" hrefLang="fr-dz" href="https://www.ibm.com/dz-fr"/><link rel="alternate" hrefLang="pt-ao" href="https://www.ibm.com/ao-pt"/><link rel="alternate" hrefLang="en-ai" href="https://www.ibm.com/ai-en"/><link rel="alternate" hrefLang="en-ag" href="https://www.ibm.com/ag-en"/><link rel="alternate" hrefLang="es-ar" href="https://www.ibm.com/ar-es"/><link rel="alternate" hrefLang="en-aw" href="https://www.ibm.com/aw-en"/><link rel="alternate" hrefLang="en-au" href="https://www.ibm.com/au-en"/><link rel="alternate" hrefLang="de-at" href="https://www.ibm.com/at-de"/><link rel="alternate" hrefLang="en-bs" href="https://www.ibm.com/bs-en"/><link rel="alternate" hrefLang="en-bh" href="https://www.ibm.com/bh-en"/><link rel="alternate" hrefLang="en-bd" href="https://www.ibm.com/bd-en"/><link rel="alternate" hrefLang="en-bb" href="https://www.ibm.com/bb-en"/><link rel="alternate" hrefLang="en-be" href="https://www.ibm.com/be-en"/><link rel="alternate" hrefLang="en-bm" href="https://www.ibm.com/bm-en"/><link rel="alternate" hrefLa ...

# %% [markdown]
# Creating Query String

# %%
url_get = 'http://httpbin.org/get'

# %%
payload = {"name": "Joseph", "ID": "123"}

# %%
payload
# Out:
# {'name': 'Joseph', 'ID': '123'}

# %%
r = requests.get(url_get, params = payload)

# %%
r
# Out:
# <Response [200]>

# %%
r.url
# Out:
# 'http://httpbin.org/get?name=Joseph&ID=123'

# %%
r.request.body

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '{\n  "args": {\n    "ID": "123", \n    "name": "Joseph"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.25.1", \n    "X-Amzn-Trace-Id": "Root=1-63ea5ec3-7c413d604470dfc33f7aad38"\n  }, \n  "origin": "35.196.120.95", \n  "url": "http://httpbin.org/get?name=Joseph&ID=123"\n}\n'

# %%
r.headers
# Out:
# {'Date': 'Mon, 13 Feb 2023 16:01:07 GMT', 'Content-Type': 'application/json', 'Content-Length': '367', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
r.headers['Content-Type']
# Out:
# 'application/json'

# %%
r.json()
# Out:
# {'args': {'ID': '123', 'name': 'Joseph'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.25.1',
#   'X-Amzn-Trace-Id': 'Root=1-63ea5ec3-7c413d604470dfc33f7aad38'},
#  'origin': '35.196.120.95',
#  'url': 'http://httpbin.org/get?name=Joseph&ID=123'}

# %%
r.json()['args']
# Out:
# {'ID': '123', 'name': 'Joseph'}

# %% [markdown]
# POST Request

# %%
url_post = 'http://httpbin.org/post'

# %%
payload = {"name": "Joseph", "ID": "123"}

# %%
response_post = requests.post(url_post, data = payload)

# %%
print('POST request url:', response_post.url)
# Out:
# POST request url: http://httpbin.org/post

# %%
print('GET request URL:', r.url)
# Out:
# GET request URL: http://httpbin.org/get?name=Joseph&ID=123

# %%
print("POST request body:", response_post.request.body)
print("GET request body:", r.request.body)
# Out:
# POST request body: name=Joseph&ID=123
# GET request body: None

# %%
response_post.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'ID': '123', 'name': 'Joseph'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '18',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.25.1',
#   'X-Amzn-Trace-Id': 'Root=1-63ea6043-56adb88576de1f2803cfd3f3'},
#  'json': None,
#  'origin': '35.196.120.95',
#  'url': 'http://httpbin.org/post'}

# %%
response_post.json()['form']
# Out:
# {'ID': '123', 'name': 'Joseph'}

# %% [markdown]
# <--practice-->

# %%
import requests
import os 
from PIL import Image
from IPython.display import IFrame

# %%
url='https://www.ibm.com/'
r=requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
print(r.request.headers)
# Out:
# {'User-Agent': 'python-requests/2.25.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': '_abck=DE4C558EAE49400E3D6F878992C789B9~-1~~-1~-1~-1; bm_sz=B4F7DA3249D6E17929E243ADB01CC4EA~~4470084~4600372'}

# %%
print("request body:", r.request.body)
# Out:
# request body: None

# %%
header=r.headers
print(r.headers)
# Out:
# {'Server': 'Apache', 'Last-Modified': 'Fri, 10 Feb 2023 16:57:49 GMT', 'ETag': '"125fc-5f45b65b483b2-gzip"', 'Accept-Ranges': 'bytes', 'Content-Type': 'text/html', 'Cache-Control': 'max-age=3600', 'Expires': 'Mon, 13 Feb 2023 17:21:11 GMT', 'X-Akamai-Transformed': '9 16605 0 pmb=mTOE,2', 'Content-Encoding': 'gzip', 'Date': 'Mon, 13 Feb 2023 16:21:11 GMT', 'Content-Length': '16799', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'x-content-type-options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Content-Security-Policy': 'upgrade-insecure-requests', 'Strict-Transport-Security': 'max-age=31536000'}

# %%
header['date']
# Out:
# 'Mon, 13 Feb 2023 16:21:11 GMT'

# %%
header['Content-Type']
# Out:
# 'text/html'

# %%
r
# Out:
# <Response [200]>

# %%
 r.encoding
# Out:
# 'ISO-8859-1'

# %%
r.text[0:100]
# Out:
# '<!DOCTYPE html><html lang="en-US"><head><meta name="viewport" content="width=device-width"/><meta ch'

# %%
# Use single quotation marks for defining string
url='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/IDSNlogo.png'

# %%
r=requests.get(url)

# %%
print(r.headers)
# Out:
# {'Date': 'Mon, 13 Feb 2023 16:22:38 GMT', 'X-Clv-Request-Id': '9b5fceb8-d40e-4fc2-97ee-1a746de5b621', 'Server': 'Cleversafe', 'X-Clv-S3-Version': '2.5', 'Accept-Ranges': 'bytes', 'x-amz-request-id': '9b5fceb8-d40e-4fc2-97ee-1a746de5b621', 'ETag': '"8bb44578fff8fdcc3d2972be9ece0164"', 'Content-Type': 'image/png', 'Last-Modified': 'Wed, 16 Nov 2022 03:32:41 GMT', 'Content-Length': '78776'}

# %%
r.headers['Content-Type']
# Out:
# 'image/png'

# %%
# Current Working Directory
os.getcwd()
# Out:
# '/content'

# %%
path = os.path.join(os.getcwd(),'image.png')
path
# Out:
# '/content/image.png'

# %%
with open(path,'wb') as f:
    f.write(r.content)

# %%
Image.open(path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1880x656 at 0x7F16C5830310>

# %% [markdown]
# Get Request with URL Parameters

# %%
url_get='http://httpbin.org/get'

# %%
payload={"name":"Joseph","ID":"123"}

# %%
r=requests.get(url_get,params=payload)

# %%
r.url
# Out:
# 'http://httpbin.org/get?name=Joseph&ID=123'

# %%
print("request body:", r.request.body)
print(r.status_code)
print(r.text)
# Out:
# request body: None
# 200
# {
#   "args": {
#     "ID": "123",
#     "name": "Joseph"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-63ea6532-11b2b3ad1a99f3282374cd7c"
#   },
#   "origin": "35.196.120.95",
#   "url": "http://httpbin.org/get?name=Joseph&ID=123"
# }

# %%
r.headers['Content-Type']
# Out:
# 'application/json'

# %%
r.json()
# Out:
# {'args': {'ID': '123', 'name': 'Joseph'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.25.1',
#   'X-Amzn-Trace-Id': 'Root=1-63ea6532-11b2b3ad1a99f3282374cd7c'},
#  'origin': '35.196.120.95',
#  'url': 'http://httpbin.org/get?name=Joseph&ID=123'}

# %%
r.json()['args']
# Out:
# {'ID': '123', 'name': 'Joseph'}
