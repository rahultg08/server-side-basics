# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 KB 505.3 kB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for openai: filename=openai-0.26.4-py3-none-any.whl size=67744 sha256=e12547154fd5f9ba115836c7ad25ba6ced6492b43b89201da57385dc73702613
#   Stored in directory: /root/.cache/pip/wheels/2b/d8/4e/268f029bd3277c1dd9e8781a0e0296e0a63822665bfa2429fc
# Successfully built openai
# ...

# %%
import os
import openai

openai.api_key ="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"

response = openai.Completion.create(
  model="text-davinci-003",
  prompt="hello world using python",
  temperature=0.7,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)
wanted=response["choices"][0]
print(wanted["text"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-ad530d7ed82c> in <module>
#       1 import os
# ----> 2 import openai
#       3
#       4 openai.api_key ="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"
#       5
#
# ModuleNotFoundError: No module named 'openai'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
